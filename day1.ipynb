# %% [markdown]
# # Data types

# %%
l=[1,3,4,5,56,7]

# %%
type(l)
# Out:
# list

# %%
l[3:2]
# Out:
# []

# %%
l[0:2]
# Out:
# [1, 3]

# %%
l+l
# Out:
# [1, 3, 4, 5, 56, 7, 1, 3, 4, 5, 56, 7]

# %%
# duplic n times and add it "list*n"
l*4
# Out:
# [1, 3, 4, 5, 56, 7, 1, 3, 4, 5, 56, 7, 1, 3, 4, 5, 56, 7, 1, 3, 4, 5, 56, 7]

# %%
# print list
l
# Out:
# [1, 3, 4, 5, 56, 7]

# %%
# find the data at index 2 and return it
l[2]
# Out:
# 4

# %%
# data get from index 0 to 2
l[0:3]
# Out:
# [1, 3, 4]

# %%
# replace the value in index three
l[3]=15
l
# Out:
# [1, 3, 4, 15, 56, 7]

# %%
# delete item and it does not return any item 
del l[1]
l
# Out:
# [1, 4, 15, 56, 7]

# %%
# finding length -- it return a number
len(l)
# Out:
# 5

# %%
# reverse a list
# print before revers
print("list before reverse ", l)
# print after revere
l[::-1]
# Out:
# list before reverse  [1, 4, 15, 56, 7]
# [7, 56, 15, 4, 1]

# %%
# add or append the value at end
l.append(6)
l
# Out:
# [1, 4, 15, 56, 7, 6]

# %%
# add or append a list
b=['sreenu','chandu', 'vishnu']
l.extend(b)
l
# Out:
# [1, 4, 15, 56, 7, 6, 'sreenu', 'chandu', 'vishnu']

# %%
# value insert at particular position based on index
l.insert(2,"sai")
l
# Out:
# [1, 4, 'sai', 15, 56, 7, 6, 'sreenu', 'chandu', 'vishnu']

# %%
# removes the value from list
l.remove('sai')
l
# Out:
# [1, 4, 15, 56, 7, 6, 'sreenu', 'chandu', 'vishnu']

# %%
# find the index of value
# if value is in list then return index else it returns valueError: "value" is not in list
l.index(15)
# Out:
# 2

# %%
a=l*5

# %%
# find the count of the value
# if the value is not exists in list return 0 else return count of value
a.count('sreenu')
# Out:
# 5

# %%
# pop or delete the element by using and  return the value of that
a.pop(15)
# Out:
# 'sreenu'

# %%
# reverse the list
l.reverse()
l
# Out:
# ['vishnu', 'chandu', 'sreenu', 6, 7, 56, 15, 4, 1]

# %%
# sort the list
l= [3,5,2,0,6,7,1,5,]
l.sort()
l
# Out:
# [0, 1, 2, 3, 5, 5, 6, 7]

# %%
# remove all the list
a.clear()
a
# Out:
# []

# %% [markdown]
# # Tuple:
#     - Tuple in python is similar to list.
#     - Tuples are immutable
#     - Immutable means, once you have declared the tuple you cannot perform add, delete, or update operations

# %%
# create a tuple
a=('sreenu','chnadu','vishnu', 'sai','sudhakar','sreeni')

# %%
#print tuple

# %% [markdown]
# ## Dictinary
#     - It is key value based datatype.
#     - it can store data into key value pair format

# %%
# create directory by using dict() method
d=dict()

# %%
# find the type of dictinary
type(d)
# Out:
# dict

# %%
# 2nd way to create dictinary
d1= {
    'name':'sree',
    'age': '24',
    'id':'2343',
    'num':3
}

# %%
type(d1)
# Out:
# dict

# %%
# example
my_phone_book={
    'name':['sreenu', 'chandu'],
    'phone':['345567','45576787'],
    'email':['sree@gmail.com','chandu@gmail.com']
    
}

# %%
# print phone book
my_phone_book
# Out:
# {'name': ['sreenu', 'chandu'],
#  'phone': ['345567', '45576787'],
#  'email': ['sree@gmail.com', 'chandu@gmail.com']}

# %%
# Finding a keys in phone book
my_phone_book.keys()
# Out:
# dict_keys(['name', 'phone', 'email'])

# %%
# To get the values from my_phone_book
my_phone_book.values()
# Out:
# dict_values([['sreenu', 'chandu'], ['345567', '45576787'], ['sree@gmail.com', 'chandu@gmail.com']])

# %%
# To Add a new key value pair
my_phone_book['id']=[1,2]
my_phone_book
# Out:
# {'name': ['sreenu', 'chandu'],
#  'phone': ['345567', '45576787'],
#  'email': ['sree@gmail.com', 'chandu@gmail.com'],
#  'id': [1, 2]}

# %%
my_phone_book['name'][0]
# Out:
# 'sreenu'

# %%
del my_phone_book['id']
my_phone_book
# Out:
# {'name': ['sreenu', 'chandu'],
#  'phone': ['345567', '45576787'],
#  'email': ['sree@gmail.com', 'chandu@gmail.com']}

# %%
# finding the length of the my_phone_book
len(my_phone_book)
# Out:
# 3

# %%
# to clear the dictionary or to make empty.
my_phone_book.clear()

# %% [markdown]
# ### SET
#     - set is an unordered collection of unique elements or items
#     -

# %%
# create a set 1st way
a={4,5,6,7,4,6,7}

# %%
print(a)
type(a)
# Out:
# {4, 5, 6, 7}
# set

# %%
# 2nd way to create  a set
b=set({4,6,7,8,8,0})
type(b)
# Out:
# set

# %%
## Set operations Unioun operator (|)
a|b
# Out:
# {0, 4, 5, 6, 7, 8}

# %%
# intersection operator (&)
a&b
# Out:
# {4, 6, 7}

# %%
# diffece operation where elements present in a and b are deleted and remaining elements of a is the result
a-b
# Out:
# {5}

# %%
# Symmetrical diffrence operation where the intersectiong elements are deleted and the remain element in both sets
print(a^b)
# Out:
# {0, 5, 8}
